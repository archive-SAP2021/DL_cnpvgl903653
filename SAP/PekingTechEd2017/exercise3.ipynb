# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# import tabular data IO
temp = './pandas/{}.csv'
# %time apple_stock = pd.read_csv(temp.format('apple'), sep='\t', parse_dates=['Date'])
type(apple_stock)
# Out:
# CPU times: user 16 ms, sys: 0 ns, total: 16 ms
# Wall time: 12.8 ms
# pandas.core.frame.DataFrame

# %%
apple_stock.head()
# Out:
#         Date   Open   High    Low  Close     Volume
# 0 2007-01-03  12.33  12.37  11.70  11.97  311433248
# 1 2007-01-04  12.01  12.28  11.97  12.24  214031636
# 2 2007-01-05  12.25  12.31  12.06  12.15  208817119
# 3 2007-01-08  12.28  12.36  12.18  12.21  199431337
# 4 2007-01-09  12.35  13.28  12.16  13.22  838036682

# %%
apple_stock.index.name='Date'

# %%
apple_stock.columns.values
# Out:
# array(['Date', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype=object)

# %%
# operation on original data frame
apple_stock_ts = apple_stock.set_index('Date')['Close']
print(type(apple_stock_ts))
apple_stock_ts.head(20)
# Out:
# <class 'pandas.core.series.Series'>
# Date
# 2007-01-03    11.97
# 2007-01-04    12.24
# 2007-01-05    12.15
# 2007-01-08    12.21
# 2007-01-09    13.22
# 2007-01-10    13.86
# 2007-01-11    13.69
# 2007-01-12    13.52
# 2007-01-16    13.87
# 2007-01-17    13.56
# 2007-01-18    12.72
# 2007-01-19    12.64
# 2007-01-22    12.40
# 2007-01-23    12.24
# 2007-01-24    12.39
# 2007-01-25    12.32
# 2007-01-26    12.20
# 2007-01-29    12.28
# 2007-01-30    12.22
# 2007-01-31    12.25
# Name: Close, dtype: float64

# %%
apple_stock_ts.resample('M', how=['mean', 'median', 'std'])
# Out:
# /home/dluser1/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...)..apply(<func>)
#   """Entry point for launching an IPython kernel.
#                   mean   median       std
# Date
# 2007-01-31   12.697500   12.355  0.651693
# 2007-02-28   12.247895   12.130  0.275934
# 2007-03-31   12.943636   12.850  0.438499
# 2007-04-30   13.387000   13.370  0.426233
# 2007-05-31   15.543182   15.575  0.826198
# 2007-06-30   17.383333   17.410  0.301070
# 2007-07-31   19.442857   19.610  0.875021
# 2007-08-31   18.549130   18.840  0.857840
# 2007-09-30   20.295789   20.040  1.012639
# 2007-10-31   24.544783   24.230  1.552148
# 2007-11-30   24.951905   24.650  1.455753
# 2007-12-31   27.215000   27.235  0.944538
# 2008-01-31   22.909048   23.050  3.130891
# 2008-02-29   17.880000   17.820  0.613720
# 2008-03-31   18.688000   18.235  1.193370
# 2008-04-30   22.598636   22.075  1.332142
# ...

# %%
apple_stock_ts.plot()

# %%
plt.show()
